# %%
# for strings

# %%
a = 12
type(a)
# Out:
# int

# %%
a = 1.2
type(a)
# Out:
# float

# %%
a = "anand"
type(a)
# Out:
# str

# %%
str = "anand kumar"
print(str)
# Out:
# anand kumar

# %%
str.capitalize()
# Out:
# 'Anand kumar'

# %%
str.count("k")
# Out:
# 1

# %%
str.endswith("d")
# Out:
# False

# %%
str.find("d")
# Out:
# 4

# %%
str.index("k")
# Out:
# 6

# %%
str.isupper()
# Out:
# False

# %%
str.isalnum()
# Out:
# False

# %%
str.isascii()
# Out:
# True

# %%
str.lower()
# Out:
# 'anand kumar'

# %%
str.split()
# Out:
# ['anand', 'kumar']

# %%
str.title()
# Out:
# 'Anand Kumar'

# %%
str.upper()
# Out:
# 'ANAND KUMAR'

# %%
# for list

# %%
lst = [1,1.2,"anand",[3,3.4,"kumar"]]
print(lst)
# Out:
# [1, 1.2, 'anand', [3, 3.4, 'kumar']]

# %%
lst.append(5)
print(lst)
# Out:
# [1, 1.2, 'anand', [3, 3.4, 'kumar'], 5]

# %%
lst.insert(6,7)
print(lst)
# Out:
# [1, 1.2, 'anand', [3, 3.4, 'kumar'], 5, 7]

# %%
lst.index(lst[2])
# Out:
# 2

# %%
lst.remove(7)
print(lst)
# Out:
# [1, 1.2, 'anand', [3, 3.4, 'kumar'], 5]

# %%
lst.pop(lst[0])
print(lst)
# Out:
# [1, 'anand', [3, 3.4, 'kumar'], 5]

# %%
lst.reverse()
print(lst)
# Out:
# [5, [3, 3.4, 'kumar'], 'anand', 1]

# %%
lst.extend([1.2])

# %%
print(lst)
# Out:
# [5, [3, 3.4, 'kumar'], 'anand', 1, 1.2]

# %%
lst.remove(5)
print(lst)
# Out:
# [[3, 3.4, 'kumar'], 'anand', 1, 1.2]

# %%
# for dictionaries

# %%
dic = {"name":"anand","last name":"kumar","P no":"1234567890"}
print(dic)
# Out:
# {'name': 'anand', 'last name': 'kumar', 'P no': '1234567890'}

# %%
print(dic["name"])
# Out:
# anand

# %%
dic.get("last name")
# Out:
# 'kumar'

# %%
dic.fromkeys("P no")
# Out:
# {'P': None, ' ': None, 'n': None, 'o': None}

# %%
dic.items()
# Out:
# dict_items([('name', 'anand'), ('last name', 'kumar'), ('P no', '1234567890')])

# %%
dic.keys()
# Out:
# dict_keys(['name', 'last name', 'P no'])

# %%
dic.pop("name")
# Out:
# 'anand'

# %%
print(dic)
# Out:
# {'last name': 'kumar', 'P no': '1234567890'}

# %%
dic.update({"name":"anand"})
print(dic)
# Out:
# {'last name': 'kumar', 'P no': '1234567890', 'name': 'anand'}

# %%
dic = {"name":"anand","last name":"kumar","P no":"1234567890"}
print(dic)
# Out:
# {'name': 'anand', 'last name': 'kumar', 'P no': '1234567890'}

# %%
dic.values()
# Out:
# dict_values(['anand', 'kumar', '1234567890'])

# %%
dic.keys()
# Out:
# dict_keys(['name', 'last name', 'P no'])

# %%
dic.get("name")
# Out:
# 'anand'

# %%
# for sets

# %%
set = {1,1.2,"anand"}
print(set)
# Out:
# {1, 'anand', 1.2}

# %%
set.add(2)
print(set)
# Out:
# {1, 2, 'anand', 1.2}

# %%
set.difference()
# Out:
# {1, 1.2, 2, 'anand'}

# %%
set1 = {1,"kumar",6}

# %%
set.intersection(set1)
# Out:
# {1}

# %%
set.pop()
# Out:
# 1

# %%
set.remove("anand")

# %%
print(set)
# Out:
# {2, 1.2}

# %%
set.symmetric_difference(set1)
# Out:
# {1, 1.2, 2, 6, 'kumar'}

# %%
set.union(set1)
# Out:
# {1, 1.2, 2, 6, 'kumar'}

# %%
set.update({4})

# %%
print(set)
# Out:
# {1.2, 2, 4}

# %%
# for tuples

# %%
tup = ('anand','kumar',12)
print(tup)
# Out:
# ('anand', 'kumar', 12)

# %%
tup.count("a")
# Out:
# 0

# %%
tup.index("anand")
# Out:
# 0
