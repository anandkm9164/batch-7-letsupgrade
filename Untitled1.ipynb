# %%
Anand = int(input("Enter your plane altitude \n"))


if (Anand <= 1000):
    print("Safe to land")
elif ( Anand > 1000 and Anand <= 5000):
    print("Bring down to 1000")
else:
    print("Turn Around")
# Out:
# Enter your plane altitude
#  1000
# Safe to land
